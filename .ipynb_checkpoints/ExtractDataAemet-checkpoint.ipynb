# %%
import requests
import pandas as pd

# %%
# One call API OpenWaetherData

latitud, longitud = 36.0127, -5.60295
APIKeyOpenWeather = '3c08d56033dbf63eb861caf5c5e30ccd'

url ='https://api.openweathermap.org/data/2.5/onecall?lat=' + str(latitud) + '&lon=' + str(longitud) +'&exclude=current,minutely,dayly,alert&units=metric&appid=' + APIKeyOpenWeather

# %%
r = requests.get(url)
json = r.json()
json['hourly'] # Hourly Forecast 48h Tarifa
# Out:
# [{'dt': 1621681200,
#   'temp': 26.94,
#   'feels_like': 28.08,
#   'pressure': 1013,
#   'humidity': 61,
#   'dew_point': 18.78,
#   'uvi': 8.41,
#   'clouds': 18,
#   'visibility': 10000,
#   'wind_speed': 5.38,
#   'wind_deg': 252,
#   'wind_gust': 5.26,
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'pop': 0},
#  {'dt': 1621684800,
#   'temp': 25.86,
#   'feels_like': 26.09,
#   'pressure': 1013,
#   'humidity': 61,
#   'dew_point': 17.77,
#   'uvi': 9.53,
#   'clouds': 21,
#   'visibility': 10000,
#   'wind_speed': 5.99,
#   'wind_deg': 260,
#   'wind_gust': 6.27,
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'pop': 0},
#  {'dt': 1621688400,
#   'temp': 24.76,
#   'feels_like': 24.88,
#   'pressure': 1013,
#   'humidity': 61,
#   'dew_point': 16.74,
#   'uvi': 9.68,
#   'clouds': 50,
#   'visibility': 10000,
#   'wind_speed': 5.97,
# ...

# %%
# AEMET

url = 'https://opendata.aemet.es/opendata/api/prediccion/especifica/montaña/pasada/area/peu1'
api_key = "eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJqYXZpZXJsaXJvQGdtYWlsLmNvbSIsImp0aSI6ImJlNDk5MGJmLWI3NGItNDVhZi1hMzFiLWVhNTczOWVhZDQ5NCIsImlzcyI6IkFFTUVUIiwiaWF0IjoxNjIwODA1NDQxLCJ1c2VySWQiOiJiZTQ5OTBiZi1iNzRiLTQ1YWYtYTMxYi1lYTU3MzllYWQ0OTQiLCJyb2xlIjoiIn0.haVMyUZcNfyDl69AfjDd6W5vB7xBOUZrFDpWRgXAfHM"

querystring = {"api_key":api_key}
headers = {'cache-control': "no-cache"}

r = requests.get(url, headers=headers, params=querystring)

requests.get(r.json()['datos']).json()
# Out:
# [{'origen': {'productor': 'Agencia Estatal de Meteorología - AEMET - Gobierno de España',
#    'web': 'http://www.aemet.es',
#    'tipo': 'Predicción de montaña',
#    'language': 'es',
#    'copyright': '© AEMET. Autorizado el uso de la información y su reproducción citando a AEMET como autora de la misma.',
#    'notaLegal': 'http://www.aemet.es/es/nota_legal'},
#   'seccion': [{'apartado': [],
#     'lugar': [],
#     'parrafo': [{'texto': '20 de mayo ', 'numero': '1'},
#      {'texto': 'Día soleado, con intervalos de nubes altas.', 'numero': '2'},
#      {'texto': 'TEMPERATURAS MÍNIMAS:', 'numero': '3'},
#      {'texto': '5ºCen Soto de Valdeón, 6ºC en Fuente Dé y Tama, 7ºC en Amieva y Carreña de Cabrales, 8ºC en Tresviso.',
#       'numero': '4'},
#      {'texto': 'TEMPERATURAS MÁXIMAS: ', 'numero': '5'},
#      {'texto': '24ºC en Amieva, Carreña de Cabrales y Tama; 23ºC en Fuente Dé; 21ºC en Soto de Valdeón, 19ºC en Tresviso.',
#       'numero': '6'},
# ...

# %%
# MICRO WINDGURU

url = 'http://micro.windguru.cz/?s=53&m=all'
r = requests.get(url)

r.text
# Out:
# '<!DOCTYPE html>\n<html>\n<head>\n<title>micro.windguru.cz</title>\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n<meta name="Robots" content="noindex,nofollow">\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<style>\nbody { font-family: monospace; }\n</style>\n</head>\n<body>\n<pre>\nWindguru forecast\n\nUnited States - Maui (north shore),  lat: 20.935, lon: -156.36, alt: 1, SST: 25 C\n\nGFS 13 km (init: 2021-05-17 12 UTC)\n\n        Date    WSPD    GUST   WDIRN    WDEG     TMP     SLP    HCLD    MCLD    LCLD    APCP   APCP1      RH\n    (UTC-10)   knots   knots    dir.    deg.       C     hPa       %       %       %   mm/3h   mm/1h       %\n\n Mon 17. 02h      12      17       E      82      20    1018       -       -       -       -       -      73\n Mon 17. 03h      12      16       E      81      20    1018       0       0      30       -       0      75\n Mon 17. 04h      12      16       E      85      20    1017       0       0  
# ...

# %%
# Exploring data of NOAA ...
url_start = 'https://www.ncei.noaa.gov/access/services/data/v1'
dataset = '?dataset=daily-summaries'
stationIdentifier = '&stations=USC00457180,USC00390043'
startDate = '&startDate=2020-01-01'
endDate = '&endDate=2020-01-03'
dataTypes = '&dataTypes=MLY-PRCP-NORMAL,MLY-TMIN-NORMAL'
boundingBox = '&boundingBox=36.007573,-5.608402,35.007573,-4.608402'
formato = '&format=json'

# %%
url = url_start + dataset+ stationIdentifier + startDate + endDate + dataTypes
url
# Out:
# 'https://www.ncei.noaa.gov/access/services/data/v1?dataset=daily-summaries&stations=USC00457180,USC00390043&startDate=2020-01-01&endDate=2020-01-03&dataTypes=MLY-PRCP-NORMAL,MLY-TMIN-NORMAL'

# %%
r = requests.get(url)

# %%
r.content
# Out:
# b'"STATION","DATE","MLY-PRCP-NORMAL","MLY-TMIN-NORMAL"\n"USC00457180","2020-01-01",,\n"USC00457180","2020-01-02",,\n"USC00457180","2020-01-03",,\n"USC00390043","2020-01-01",,\n"USC00390043","2020-01-02",,\n"USC00390043","2020-01-03",,\n'
